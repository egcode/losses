# %% [markdown]
# ## Import modules

# %%
import os
import numpy as np
import tensorflow as tf
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data

slim = tf.contrib.slim
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
print(tf.__version__)

NUM_CLASSES = 10
NUM_PARALLEL_CALLS = 2 # number of cpu cores
BATCH_SIZE = 7
REPEAT_DATASET = 1
# Out:
# 1.12.0

# %% [markdown]
# ## Dataset setup

# %%
import mnist_reader
train_images, train_labels = mnist_reader.load_mnist('datasets/fashion_mnist', kind='train')
test_images, test_labels = mnist_reader.load_mnist('datasets/fashion_mnist', kind='t10k')

# %%
print("\n-------------------------------")
print("train_images shape: " + str(train_images.shape))
print("train_labels shape: " + str(train_labels.shape))
print("valid_images shape: " + str(test_images.shape))
print("valid_labels shape: " + str(test_labels.shape))
print("-------------------------------\n")
# Out:
# -------------------------------
# train_images shape: (60000, 28, 28, 1)
# train_labels shape: (60000,)
# valid_images shape: (10000, 28, 28, 1)
# valid_labels shape: (10000,)
# -------------------------------

# %%
# create the training datasets
dx_train = tf.data.Dataset.from_tensor_slices(train_images)

# apply a one-hot transformation to each label for use in the neural network
dy_train = tf.data.Dataset.from_tensor_slices(train_labels)
dy_train = dy_train.map(lambda z: tf.one_hot(z, 10), num_parallel_calls=NUM_PARALLEL_CALLS)
dy_train = dy_train.repeat()

# zip the x and y training data together and shuffle, batch etc.
train_dataset = tf.data.Dataset.zip((dx_train, dy_train)).shuffle(500)
train_dataset = train_dataset.repeat(REPEAT_DATASET)
train_dataset = train_dataset.batch(BATCH_SIZE)

# do the same for validation set
dx_valid = tf.data.Dataset.from_tensor_slices(test_images)
dy_valid = tf.data.Dataset.from_tensor_slices(test_labels)
dy_valid = dy_valid.map(lambda z: tf.one_hot(z, 10), num_parallel_calls=NUM_PARALLEL_CALLS)
dy_valid = dy_valid.repeat()

test_dataset = tf.data.Dataset.zip((dx_valid, dy_valid)).shuffle(500)
test_dataset = test_dataset.repeat(REPEAT_DATASET)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
# create general iterator
iterator = tf.data.Iterator.from_structure(train_dataset.output_types,
                                            train_dataset.output_shapes)
next_batch = iterator.get_next()

# make datasets that we can initialize separately, but using the same structure via the common iterator
training_init_op = iterator.make_initializer(train_dataset)
test_init_op = iterator.make_initializer(test_dataset)

# %% [markdown]
# ## Model setup

# %%
with tf.name_scope('input'):
    input_images = tf.placeholder(tf.float32, shape=(None,28,28,1), name='input_images')
    labels = tf.placeholder(tf.int64, shape=(None, NUM_CLASSES), name='labels')
    
global_step = tf.Variable(0, trainable=False, name='global_step')


def parametric_relu(_x):
  alphas = tf.get_variable('alpha', _x.get_shape()[-1],
                       initializer=tf.constant_initializer(0.0),
                        dtype=tf.float32)
  pos = tf.nn.relu(_x)
  neg = alphas * (_x - abs(_x)) * 0.5

  return pos + neg


def inference(input_images):
    with slim.arg_scope([slim.conv2d], kernel_size=3, padding='SAME'):
        with slim.arg_scope([slim.max_pool2d], kernel_size=2):
            
            x = slim.conv2d(input_images, num_outputs=32, scope='conv1_1')
            x = slim.conv2d(x, num_outputs=32, scope='conv1_2')
            x = slim.max_pool2d(x, scope='pool1')
     
            x = slim.conv2d(x, num_outputs=64, scope='conv2_1')
            x = slim.conv2d(x, num_outputs=64, scope='conv2_2')
            x = slim.max_pool2d(x, scope='pool2')
            
            x = slim.conv2d(x, num_outputs=128, scope='conv3_1')
            x = slim.conv2d(x, num_outputs=128, scope='conv3_2')
            x = slim.max_pool2d(x, scope='pool3')
            
            x = slim.flatten(x, scope='flatten')
            
            features3d = slim.fully_connected(x, num_outputs=3, activation_fn=None, scope='fc0')
            features2d = slim.fully_connected(features3d, num_outputs=2, activation_fn=None, scope='fc1')

            x = parametric_relu(features2d)
            x = slim.fully_connected(x, num_outputs=10, activation_fn=None, scope='fc2')
    
    return x, features2d, features3d

# %%
def loss(logits, ratio=0.5):
    with tf.name_scope('loss'):
        with tf.name_scope('softmax_loss'):
            softmax_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=labels, logits=logits))
        with tf.name_scope('total_loss'):
            total_loss = softmax_loss # + ratio * center_loss

    with tf.name_scope('loss/'):
        tf.summary.scalar('SoftmaxLoss', softmax_loss)
        tf.summary.scalar('TotalLoss', total_loss)
        
    return total_loss

def accuracy(labels):
    with tf.name_scope('acc'):
        prediction = tf.argmax(logits, 1)
        equality = tf.equal(prediction, tf.argmax(labels, 1))
        accuracy = tf.reduce_mean(tf.cast(equality, tf.float32))
    return accuracy

# %%
logits, features2d, features3d = inference(input_images)
loss = loss(logits)
accuracy = accuracy(labels)
optimizer = tf.train.AdamOptimizer(0.001).minimize(loss, global_step=global_step)

# %%
init_op = tf.global_variables_initializer()
summary_op = tf.summary.merge_all()

# %% [markdown]
# ## Training the model

# %%
mean_data = np.mean(train_images, axis=0)

# %%
# run the training
epochs = 8000
sess = tf.Session()
sess.run(tf.global_variables_initializer())

sess.run(init_op)
sess.run(training_init_op)

writer = tf.summary.FileWriter('/tmp/mnist_log', sess.graph)
# Start Tensorflow from this file 'tensorboard --logdir=/tmp/mnist_log'

for i in range(epochs):

    img_batch, label_batch = sess.run(next_batch)
    l, _, acc, summary_str = sess.run([loss, optimizer, accuracy, summary_op],
                                         feed_dict={input_images: img_batch-mean_data,labels: label_batch})

    writer.add_summary(summary_str, global_step=epochs)

    if i % 50 == 0:
        print("Epoch: {}, loss: {:.3f}, training accuracy: {:.2f}%".format(i, l, acc * 100))            


# now setup the validation run
test_iters = 100
# re-initialize the iterator, but this time with validation data
sess.run(test_init_op)
avg_acc = 0
for i in range(test_iters):
    img_batch, label_batch = sess.run(next_batch)
    acc = sess.run([accuracy], feed_dict={input_images: img_batch-mean_data,labels: label_batch})
    avg_acc += acc[0]
print("Average validation set accuracy over {} iterations is {:.2f}%".format(test_iters, (avg_acc / test_iters) * 100))
# Out:
# Epoch: 0, loss: 2.303, training accuracy: 0.00%
# Epoch: 50, loss: 2.300, training accuracy: 28.57%
# Epoch: 100, loss: 2.293, training accuracy: 28.57%
# Epoch: 150, loss: 2.304, training accuracy: 0.00%
# Epoch: 200, loss: 2.474, training accuracy: 28.57%
# Epoch: 250, loss: 1.911, training accuracy: 42.86%
# Epoch: 300, loss: 1.664, training accuracy: 42.86%
# Epoch: 350, loss: 1.914, training accuracy: 14.29%
# Epoch: 400, loss: 1.770, training accuracy: 14.29%
# Epoch: 450, loss: 2.256, training accuracy: 14.29%
# Epoch: 500, loss: 2.178, training accuracy: 0.00%
# Epoch: 550, loss: 2.151, training accuracy: 0.00%
# Epoch: 600, loss: 1.806, training accuracy: 28.57%
# Epoch: 650, loss: 2.277, training accuracy: 42.86%
# Epoch: 700, loss: 1.776, training accuracy: 42.86%
# Epoch: 750, loss: 1.171, training accuracy: 57.14%
# Epoch: 800, loss: 2.400, training accuracy: 14.29%
# Epoch: 850, loss: 1.257, training accuracy: 42.86%
# Epoch: 900, loss: 1.295, training accuracy: 42.86%
# Epoch: 950, loss: 1.487, training accuracy: 28.57%
# Epoch: 1000, loss: 1.208, training accuracy: 42.86%
# Epoch: 1050, loss: 1.470, training accuracy: 57.14%
# Epoch: 1100, loss: 1.204, training accuracy: 42.86%
# Epoch: 1150, loss: 1.734, training accuracy: 28.57%
# Epoch: 1200, loss: 0.867, training accuracy: 71.43%
# Epoch: 1250, loss: 1.114, training accuracy: 71.43%
# Epoch: 1300, loss: 1.314, training accuracy: 71.43%
# Epoch: 1350, loss: 1.011, training accuracy: 42.86%
# Epoch: 1400, loss: 1.216, training accuracy: 42.86%
# Epoch: 1450, loss: 1.250, training accuracy: 71.43%
# Epoch: 1500, loss: 1.085, training accuracy: 85.71%
# Epoch: 1550, loss: 1.488, training accuracy: 28.57%
# Epoch: 1600, loss: 0.707, training accuracy: 85.71%
# Epoch: 1650, loss: 0.769, training accuracy: 71.43%
# Epoch: 1700, loss: 0.694, training accuracy: 71.43%
# Epoch: 1750, loss: 1.539, training accuracy: 28.57%
# Epoch: 1800, loss: 0.775, training accuracy: 57.14%
# Epoch: 1850, loss: 0.811, training accuracy: 71.43%
# Epoch: 1900, loss: 1.324, training accuracy: 57.14%
# Epoch: 1950, loss: 0.956, training accuracy: 57.14%
# Epoch: 2000, loss: 1.999, training accuracy: 57.14%
# Epoch: 2050, loss: 0.810, training accuracy: 57.14%
# Epoch: 2100, loss: 1.002, training accuracy: 57.14%
# Epoch: 2150, loss: 1.209, training accuracy: 71.43%
# Epoch: 2200, loss: 0.781, training accuracy: 85.71%
# Epoch: 2250, loss: 0.810, training accuracy: 71.43%
# Epoch: 2300, loss: 0.542, training accuracy: 85.71%
# Epoch: 2350, loss: 0.534, training accuracy: 71.43%
# Epoch: 2400, loss: 0.726, training accuracy: 85.71%
# Epoch: 2450, loss: 1.320, training accuracy: 57.14%
# Epoch: 2500, loss: 0.789, training accuracy: 42.86%
# Epoch: 2550, loss: 2.008, training accuracy: 14.29%
# Epoch: 2600, loss: 0.975, training accuracy: 57.14%
# Epoch: 2650, loss: 0.847, training accuracy: 57.14%
# Epoch: 2700, loss: 0.242, training accuracy: 100.00%
# Epoch: 2750, loss: 0.819, training accuracy: 71.43%
# Epoch: 2800, loss: 0.406, training accuracy: 85.71%
# Epoch: 2850, loss: 0.578, training accuracy: 71.43%
# Epoch: 2900, loss: 0.191, training accuracy: 100.00%
# Epoch: 2950, loss: 0.719, training accuracy: 85.71%
# Epoch: 3000, loss: 0.563, training accuracy: 85.71%
# Epoch: 3050, loss: 0.739, training accuracy: 42.86%
# Epoch: 3100, loss: 0.613, training accuracy: 71.43%
# Epoch: 3150, loss: 0.560, training accuracy: 71.43%
# Epoch: 3200, loss: 0.590, training accuracy: 85.71%
# Epoch: 3250, loss: 0.754, training accuracy: 71.43%
# Epoch: 3300, loss: 0.481, training accuracy: 85.71%
# Epoch: 3350, loss: 0.390, training accuracy: 85.71%
# Epoch: 3400, loss: 0.431, training accuracy: 85.71%
# Epoch: 3450, loss: 0.516, training accuracy: 85.71%
# Epoch: 3500, loss: 0.775, training accuracy: 71.43%
# Epoch: 3550, loss: 0.477, training accuracy: 85.71%
# Epoch: 3600, loss: 0.188, training accuracy: 85.71%
# Epoch: 3650, loss: 0.593, training accuracy: 71.43%
# Epoch: 3700, loss: 1.004, training accuracy: 71.43%
# Epoch: 3750, loss: 0.571, training accuracy: 71.43%
# Epoch: 3800, loss: 1.744, training accuracy: 28.57%
# Epoch: 3850, loss: 0.492, training accuracy: 71.43%
# Epoch: 3900, loss: 2.154, training accuracy: 71.43%
# Epoch: 3950, loss: 0.456, training accuracy: 85.71%
# Epoch: 4000, loss: 0.337, training accuracy: 100.00%
# Epoch: 4050, loss: 0.763, training accuracy: 71.43%
# Epoch: 4100, loss: 0.640, training accuracy: 57.14%
# Epoch: 4150, loss: 0.749, training accuracy: 57.14%
# Epoch: 4200, loss: 1.097, training accuracy: 42.86%
# Epoch: 4250, loss: 0.269, training accuracy: 85.71%
# Epoch: 4300, loss: 0.219, training accuracy: 85.71%
# Epoch: 4350, loss: 0.498, training accuracy: 71.43%
# Epoch: 4400, loss: 0.776, training accuracy: 85.71%
# Epoch: 4450, loss: 0.412, training accuracy: 85.71%
# Epoch: 4500, loss: 0.514, training accuracy: 85.71%
# Epoch: 4550, loss: 0.752, training accuracy: 42.86%
# Epoch: 4600, loss: 0.745, training accuracy: 71.43%
# Epoch: 4650, loss: 0.631, training accuracy: 85.71%
# Epoch: 4700, loss: 0.373, training accuracy: 85.71%
# Epoch: 4750, loss: 0.499, training accuracy: 85.71%
# Epoch: 4800, loss: 0.619, training accuracy: 71.43%
# Epoch: 4850, loss: 0.430, training accuracy: 71.43%
# Epoch: 4900, loss: 0.723, training accuracy: 71.43%
# Epoch: 4950, loss: 0.931, training accuracy: 71.43%
# Epoch: 5000, loss: 0.664, training accuracy: 71.43%
# Epoch: 5050, loss: 0.125, training accuracy: 100.00%
# Epoch: 5100, loss: 0.290, training accuracy: 100.00%
# Epoch: 5150, loss: 0.821, training accuracy: 71.43%
# Epoch: 5200, loss: 0.834, training accuracy: 71.43%
# Epoch: 5250, loss: 0.546, training accuracy: 71.43%
# Epoch: 5300, loss: 0.461, training accuracy: 85.71%
# Epoch: 5350, loss: 0.301, training accuracy: 85.71%
# Epoch: 5400, loss: 0.243, training accuracy: 85.71%
# Epoch: 5450, loss: 0.100, training accuracy: 100.00%
# Epoch: 5500, loss: 0.377, training accuracy: 100.00%
# Epoch: 5550, loss: 0.348, training accuracy: 85.71%
# Epoch: 5600, loss: 0.766, training accuracy: 71.43%
# Epoch: 5650, loss: 0.324, training accuracy: 85.71%
# Epoch: 5700, loss: 1.035, training accuracy: 85.71%
# Epoch: 5750, loss: 2.225, training accuracy: 42.86%
# Epoch: 5800, loss: 0.604, training accuracy: 85.71%
# Epoch: 5850, loss: 0.556, training accuracy: 85.71%
# Epoch: 5900, loss: 0.051, training accuracy: 100.00%
# Epoch: 5950, loss: 0.582, training accuracy: 85.71%
# Epoch: 6000, loss: 0.302, training accuracy: 100.00%
# Epoch: 6050, loss: 1.568, training accuracy: 42.86%
# Epoch: 6100, loss: 0.572, training accuracy: 71.43%
# Epoch: 6150, loss: 0.855, training accuracy: 42.86%
# Epoch: 6200, loss: 0.306, training accuracy: 85.71%
# Epoch: 6250, loss: 0.161, training accuracy: 100.00%
# Epoch: 6300, loss: 0.076, training accuracy: 100.00%
# Epoch: 6350, loss: 0.514, training accuracy: 71.43%
# Epoch: 6400, loss: 0.271, training accuracy: 85.71%
# Epoch: 6450, loss: 0.941, training accuracy: 71.43%
# Epoch: 6500, loss: 0.084, training accuracy: 100.00%
# Epoch: 6550, loss: 0.511, training accuracy: 85.71%
# Epoch: 6600, loss: 0.600, training accuracy: 85.71%
# Epoch: 6650, loss: 0.567, training accuracy: 85.71%
# Epoch: 6700, loss: 0.462, training accuracy: 85.71%
# Epoch: 6750, loss: 0.527, training accuracy: 85.71%
# Epoch: 6800, loss: 0.287, training accuracy: 100.00%
# Epoch: 6850, loss: 0.474, training accuracy: 85.71%
# Epoch: 6900, loss: 0.642, training accuracy: 71.43%
# Epoch: 6950, loss: 0.959, training accuracy: 42.86%
# Epoch: 7000, loss: 0.235, training accuracy: 100.00%
# Epoch: 7050, loss: 0.113, training accuracy: 100.00%
# Epoch: 7100, loss: 1.877, training accuracy: 57.14%
# Epoch: 7150, loss: 0.513, training accuracy: 71.43%
# Epoch: 7200, loss: 0.617, training accuracy: 57.14%
# Epoch: 7250, loss: 0.471, training accuracy: 71.43%
# Epoch: 7300, loss: 0.799, training accuracy: 71.43%
# Epoch: 7350, loss: 0.363, training accuracy: 85.71%
# Epoch: 7400, loss: 0.065, training accuracy: 100.00%
# Epoch: 7450, loss: 0.468, training accuracy: 85.71%
# Epoch: 7500, loss: 1.001, training accuracy: 71.43%
# Epoch: 7550, loss: 0.779, training accuracy: 57.14%
# Epoch: 7600, loss: 0.558, training accuracy: 71.43%
# Epoch: 7650, loss: 0.479, training accuracy: 71.43%
# Epoch: 7700, loss: 0.285, training accuracy: 85.71%
# Epoch: 7750, loss: 1.081, training accuracy: 42.86%
# Epoch: 7800, loss: 0.489, training accuracy: 71.43%
# Epoch: 7850, loss: 0.313, training accuracy: 100.00%
# Epoch: 7900, loss: 0.125, training accuracy: 100.00%
# Epoch: 7950, loss: 0.386, training accuracy: 85.71%
# Average validation set accuracy over 100 iterations is 81.00%

# %% [markdown]
# ## Visualize train_data

# %%
feat = sess.run(features2d, feed_dict={input_images:train_images[:20000]-mean_data})

# %matplotlib inline
import matplotlib.pyplot as plt

labels = train_labels[:20000]

f = plt.figure(figsize=(16,9))
c = ['#ff0000', '#ffff00', '#00ff00', '#00ffff', '#0000ff', 
     '#ff00ff', '#990000', '#999900', '#009900', '#009999']
for i in range(10):
    plt.plot(feat[labels==i,0].flatten(), feat[labels==i,1].flatten(), '.', c=c[i])
plt.legend(['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'])

plt.grid()
plt.show()

# %% [markdown]
# ### Visualize test_data

# %%
feat = sess.run(features2d, feed_dict={input_images:test_images[:20000]-mean_data})

# %matplotlib inline
import matplotlib.pyplot as plt

labels = test_labels[:20000]

f = plt.figure(figsize=(16,9))
c = ['#ff0000', '#ffff00', '#00ff00', '#00ffff', '#0000ff', 
     '#ff00ff', '#990000', '#999900', '#009900', '#009999']
for i in range(10):
    plt.plot(feat[labels==i,0].flatten(), feat[labels==i,1].flatten(), '.', c=c[i])
plt.legend(['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'])
plt.grid()
plt.show()

# %% [markdown]
# ### Visualize train_data 3D

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
# %matplotlib inline

feat = sess.run(features3d, feed_dict={input_images:train_images[:10000]-mean_data})
labels = train_labels[:10000]

fig = plt.figure(figsize=(16,9))
ax = plt.axes(projection='3d')

for i in range(10):
    # Data for three-dimensional scattered points
    xdata = feat[labels==i,2].flatten()
    ydata = feat[labels==i,0].flatten()
    zdata = feat[labels==i,1].flatten()
    ax.scatter3D(xdata, ydata, zdata);
ax.legend(['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'],loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# ### Visualize test_data 3D

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
# %matplotlib inline

feat = sess.run(features3d, feed_dict={input_images:test_images[:10000]-mean_data})
labels = test_labels[:10000]

fig = plt.figure(figsize=(16,9))
ax = plt.axes(projection='3d')

for i in range(10):
    # Data for three-dimensional scattered points
    xdata = feat[labels==i,2].flatten()
    ydata = feat[labels==i,0].flatten()
    zdata = feat[labels==i,1].flatten()
    ax.scatter3D(xdata, ydata, zdata);
ax.legend(['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'],loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
sess.close()
